# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading in the Dataset (Preprocess)

# %%
df = pd.read_csv('data/cleaned_merged_seasons.csv', index_col=0)
df.head()
# Out:
#   season_x                name position team_x  assists  bonus  bps  \
# 0  2016-17     Aaron Cresswell      DEF    NaN        0      0    0
# 1  2016-17        Aaron Lennon      MID    NaN        0      0    6
# 2  2016-17        Aaron Ramsey      MID    NaN        0      0    5
# 3  2016-17  Abdoulaye Doucouré      MID    NaN        0      0    0
# 4  2016-17        Adam Forshaw      MID    NaN        0      0    3
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0      454  ...           2.0     0.0             0
# 1             0         0.3      142  ...           1.0     0.0             1
# 2             0         4.9       16  ...           3.0    23.0             2
# 3             0         0.0      482  ...           1.0     0.0             0
# 4             0         1.3      286  ...           1.0     0.0             1
#
#    transfers_balance  transfers_in transfers_out  value  was_home  \
# 0                  0             0             0     55     False
# 1                  0             0             0     60      True
# 2                  0             0             0     80      True
# 3                  0             0             0     50     False
# 4                  0             0             0     45      True
#
#   yellow_cards  GW
# 0            0   1
# 1            0   1
# 2            0   1
# 3            0   1
# 4            1   1
#
# [5 rows x 37 columns]

# %%
# rearranging columns for better perception

columns = ['season_x', 'name', 'position', 'team_x', 'assists', 'bonus', 'bps',
           'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
           'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
           'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
           'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
           'team_a_score', 'team_h_score', 'threat', 'total_points',
           'transfers_balance', 'transfers_in', 'transfers_out', 'value',
           'was_home', 'yellow_cards', 'GW']

new_columns = ['name', 'season_x', 'GW', 'position', 'team_x', 'assists', 'bonus', 'bps',
               'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
               'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
               'opponent_team', 'opp_team_name', 'own_goals', 'penalties_missed',
               'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
               'team_a_score', 'team_h_score', 'threat',
               'transfers_balance', 'transfers_in', 'transfers_out', 'value',
               'was_home', 'yellow_cards',  'total_points']

df = df[new_columns]
df.head()
# Out:
#                  name season_x  GW position team_x  assists  bonus  bps  \
# 0     Aaron Cresswell  2016-17   1      DEF    NaN        0      0    0
# 1        Aaron Lennon  2016-17   1      MID    NaN        0      0    6
# 2        Aaron Ramsey  2016-17   1      MID    NaN        0      0    5
# 3  Abdoulaye Doucouré  2016-17   1      MID    NaN        0      0    0
# 4        Adam Forshaw  2016-17   1      MID    NaN        0      0    3
#
#    clean_sheets  creativity  ...  team_a_score  team_h_score  threat  \
# 0             0         0.0  ...           1.0           2.0     0.0
# 1             0         0.3  ...           1.0           1.0     0.0
# 2             0         4.9  ...           4.0           3.0    23.0
# 3             0         0.0  ...           1.0           1.0     0.0
# 4             0         1.3  ...           1.0           1.0     0.0
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# 0                  0             0              0    55     False
# 1                  0             0              0    60      True
# 2                  0             0              0    80      True
# 3                  0             0              0    50     False
# 4                  0             0              0    45      True
#
#    yellow_cards total_points
# 0             0            0
# 1             0            1
# 2             0            2
# 3             0            0
# 4             1            1
#
# [5 rows x 37 columns]

# %%
# dropping team information
# drop_columns = ['team_x', 'position', 'fixture', 'kickoff_time', 'opponent_team', 'opp_team_name']
drop_columns = ['team_x', 'fixture', 'kickoff_time']
df = df.drop(columns=drop_columns)
df.head()
# Out:
#                  name season_x  GW position  assists  bonus  bps  \
# 0     Aaron Cresswell  2016-17   1      DEF        0      0    0
# 1        Aaron Lennon  2016-17   1      MID        0      0    6
# 2        Aaron Ramsey  2016-17   1      MID        0      0    5
# 3  Abdoulaye Doucouré  2016-17   1      MID        0      0    0
# 4        Adam Forshaw  2016-17   1      MID        0      0    3
#
#    clean_sheets  creativity  element  ...  team_a_score  team_h_score  threat  \
# 0             0         0.0      454  ...           1.0           2.0     0.0
# 1             0         0.3      142  ...           1.0           1.0     0.0
# 2             0         4.9       16  ...           4.0           3.0    23.0
# 3             0         0.0      482  ...           1.0           1.0     0.0
# 4             0         1.3      286  ...           1.0           1.0     0.0
#
#    transfers_balance  transfers_in  transfers_out value  was_home  \
# 0                  0             0              0    55     False
# 1                  0             0              0    60      True
# 2                  0             0              0    80      True
# 3                  0             0              0    50     False
# 4                  0             0              0    45      True
#
#    yellow_cards  total_points
# 0             0             0
# 1             0             1
# 2             0             2
# 3             0             0
# 4             1             1
#
# [5 rows x 34 columns]

# %%
# columns that need averaging
avg_columns = ['name', 'assists', 'bonus', 'bps', 'clean_sheets',
               'creativity', 'element', 'goals_conceded', 'goals_scored', 'ict_index',
               'influence', 'minutes', 'own_goals', 'penalties_missed',
               'penalties_saved', 'red_cards', 'round', 'saves', 'selected',
               'team_a_score', 'team_h_score', 'threat', 'transfers_balance',
               'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards']

# %%
# sorting data based on name, season and gameweek
df = df.sort_values(['name', 'season_x', 'GW']).reset_index(drop = True)

# %%
df
# Out:
#                  name season_x  GW position  assists  bonus  bps  \
# 0      Aaron Connolly  2019-20   4      FWD        0      0    1
# 1      Aaron Connolly  2019-20   5      FWD        0      0    1
# 2      Aaron Connolly  2019-20   6      FWD        0      0    1
# 3      Aaron Connolly  2019-20   7      FWD        0      0    2
# 4      Aaron Connolly  2019-20   8      FWD        0      3   53
# ...               ...      ...  ..      ...      ...    ...  ...
# 98397    Ørjan Nyland  2020-21  35       GK        0      0    0
# 98398    Ørjan Nyland  2020-21  35       GK        0      0    0
# 98399    Ørjan Nyland  2020-21  36       GK        0      0    0
# 98400    Ørjan Nyland  2020-21  37       GK        0      0    0
# 98401    Ørjan Nyland  2020-21  38       GK        0      0    0
#
#        clean_sheets  creativity  element  ...  team_a_score  team_h_score  \
# 0                 0         0.1      534  ...           0.0           4.0
# 1                 0         0.3      534  ...           1.0           1.0
# 2                 0         4.8      534  ...           0.0           0.0
# 3                 0         0.6      534  ...           0.0           2.0
# 4                 1        23.8      534  ...           0.0           3.0
# ...             ...         ...      ...  ...           ...           ...
# 98397             0         0.0       35  ...           3.0           1.0
# 98398             0         0.0       35  ...           0.0           0.0
# 98399             0         0.0       35  ...           2.0           3.0
# 98400             0         0.0       35  ...           2.0           1.0
# 98401             0         0.0       35  ...           1.0           2.0
#
#        threat  transfers_balance  transfers_in  transfers_out value  was_home  \
# 0         0.0                  0             0              0    45     False
# 1        21.0              10589         13500           2911    45      True
# 2        18.0               8090         11749           3659    45     False
# 3         0.0               8437         13439           5002    45     False
# 4       107.0               2156          5952           3796    45      True
# ...       ...                ...           ...            ...   ...       ...
# 98397     0.0              -2960             0           2960    40      True
# 98398     0.0              -2960             0           2960    40      True
# 98399     0.0              -1358             0           1358    40     False
# 98400     0.0              -1782             0           1782    40     False
# 98401     0.0              -2796             0           2796    40      True
#
#        yellow_cards  total_points
# 0                 0             1
# 1                 0             1
# 2                 0             1
# 3                 0             1
# 4                 0            13
# ...             ...           ...
# 98397             0             0
# 98398             0             0
# 98399             0             0
# 98400             0             0
# 98401             0             0
#
# [98402 rows x 34 columns]

# %%
# Dividing the data into features and target
X = df.loc[:, df.columns != 'total_points']
y = df.loc[:, ['name', 'total_points']]

X[avg_columns] = X[avg_columns].groupby('name', as_index=False).rolling(3, min_periods = 1).mean().reset_index(drop = True)
features = X.set_index(['name'], drop = True).groupby('name', as_index=True).shift().dropna().reset_index()
features
# Out:
#                  name season_x    GW position  assists  bonus        bps  \
# 0      Aaron Connolly  2019-20   4.0      FWD      0.0    0.0   1.000000
# 1      Aaron Connolly  2019-20   5.0      FWD      0.0    0.0   1.000000
# 2      Aaron Connolly  2019-20   6.0      FWD      0.0    0.0   1.000000
# 3      Aaron Connolly  2019-20   7.0      FWD      0.0    0.0   1.333333
# 4      Aaron Connolly  2019-20   8.0      FWD      0.0    1.0  18.666667
# ...               ...      ...   ...      ...      ...    ...        ...
# 97408    Ørjan Nyland  2020-21  34.0       GK      0.0    0.0   0.000000
# 97409    Ørjan Nyland  2020-21  35.0       GK      0.0    0.0   0.000000
# 97410    Ørjan Nyland  2020-21  35.0       GK      0.0    0.0   0.000000
# 97411    Ørjan Nyland  2020-21  36.0       GK      0.0    0.0   0.000000
# 97412    Ørjan Nyland  2020-21  37.0       GK      0.0    0.0   0.000000
#
#        clean_sheets  creativity  element  ...       selected  team_a_score  \
# 0          0.000000    0.100000    534.0  ...       0.000000      0.000000
# 1          0.000000    0.200000    534.0  ...    7014.500000      0.500000
# 2          0.000000    1.733333    534.0  ...   12277.666667      0.333333
# 3          0.000000    1.900000    534.0  ...   23177.333333      0.333333
# 4          0.333333    9.733333    534.0  ...   30176.333333      0.000000
# ...             ...         ...      ...  ...            ...           ...
# 97408      0.000000    0.000000     35.0  ...  281394.333333      2.000000
# 97409      0.000000    0.000000     35.0  ...  278999.000000      2.333333
# 97410      0.000000    0.000000     35.0  ...  277527.000000      1.666667
# 97411      0.000000    0.000000     35.0  ...  276053.000000      1.666667
# 97412      0.000000    0.000000     35.0  ...  275057.666667      1.333333
#
#        team_h_score     threat  transfers_balance  transfers_in transfers_out  \
# 0          4.000000   0.000000           0.000000      0.000000      0.000000
# 1          2.500000  10.500000        5294.500000   6750.000000   1455.500000
# 2          1.666667  13.000000        6226.333333   8416.333333   2190.000000
# 3          1.000000  13.000000        9038.666667  12896.000000   3857.333333
# 4          1.666667  41.666667        6227.666667  10380.000000   4152.333333
# ...             ...        ...                ...           ...           ...
# 97408      1.333333   0.000000       -2122.333333      0.000000   2122.333333
# 97409      1.333333   0.000000       -2346.666667      0.000000   2346.666667
# 97410      0.666667   0.000000       -2471.000000      0.000000   2471.000000
# 97411      1.333333   0.000000       -2426.000000      0.000000   2426.000000
# 97412      1.333333   0.000000       -2033.333333      0.000000   2033.333333
#
#        value  was_home  yellow_cards
# 0       45.0  0.000000           0.0
# 1       45.0  0.500000           0.0
# 2       45.0  0.333333           0.0
# 3       45.0  0.333333           0.0
# 4       45.0  0.333333           0.0
# ...      ...       ...           ...
# 97408   40.0  0.666667           0.0
# 97409   40.0  0.666667           0.0
# 97410   40.0  0.666667           0.0
# 97411   40.0  0.666667           0.0
# 97412   40.0  0.333333           0.0
#
# [97413 rows x 33 columns]

# %%
y = y.reset_index(drop = True)
target = y.groupby('name').apply(lambda group: group.iloc[1:, :]).reset_index(drop = True).drop(columns = ['name'])
target
# Out:
#        total_points
# 0                 1
# 1                 1
# 2                 1
# 3                13
# 4                 1
# ...             ...
# 97408             0
# 97409             0
# 97410             0
# 97411             0
# 97412             0
#
# [97413 rows x 1 columns]

# %%
df = pd.concat([features, target], axis = 1)
df.head()
# Out:
#              name season_x   GW position  assists  bonus        bps  \
# 0  Aaron Connolly  2019-20  4.0      FWD      0.0    0.0   1.000000
# 1  Aaron Connolly  2019-20  5.0      FWD      0.0    0.0   1.000000
# 2  Aaron Connolly  2019-20  6.0      FWD      0.0    0.0   1.000000
# 3  Aaron Connolly  2019-20  7.0      FWD      0.0    0.0   1.333333
# 4  Aaron Connolly  2019-20  8.0      FWD      0.0    1.0  18.666667
#
#    clean_sheets  creativity  element  ...  team_a_score  team_h_score  \
# 0      0.000000    0.100000    534.0  ...      0.000000      4.000000
# 1      0.000000    0.200000    534.0  ...      0.500000      2.500000
# 2      0.000000    1.733333    534.0  ...      0.333333      1.666667
# 3      0.000000    1.900000    534.0  ...      0.333333      1.000000
# 4      0.333333    9.733333    534.0  ...      0.000000      1.666667
#
#       threat  transfers_balance  transfers_in  transfers_out value  was_home  \
# 0   0.000000           0.000000      0.000000       0.000000  45.0  0.000000
# 1  10.500000        5294.500000   6750.000000    1455.500000  45.0  0.500000
# 2  13.000000        6226.333333   8416.333333    2190.000000  45.0  0.333333
# 3  13.000000        9038.666667  12896.000000    3857.333333  45.0  0.333333
# 4  41.666667        6227.666667  10380.000000    4152.333333  45.0  0.333333
#
#    yellow_cards  total_points
# 0           0.0             1
# 1           0.0             1
# 2           0.0             1
# 3           0.0            13
# 4           0.0             1
#
# [5 rows x 34 columns]

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Lets check for any missing values

# %%
# PLot the percent of missing values per feature

missing_vals = (df.isna().sum()/df.shape[0])*100
ax = missing_vals.plot(kind='bar')
ax.set_title('% missing values per column')
ax.set_ylabel('% missing values')
plt.show()

# %% [markdown]
# Because we have so many missing values for team feature, lets drop this column entirely

# %% [markdown]
# Let's analyze the features to see which ones are categorical versus which ones are numerical

# %%
# Find which features are numerical vs. categorical for EDA

num_vars = []
cat_vars = []
num_cat_vars = []

for column in list(df.columns): 
    
    if df[column].dtype == 'float64' and len(df[column].unique()) >= 10: 
        num_vars.append(column)
    elif df[column].dtype == 'float64': 
        num_cat_vars.append(column)
    else: 
        cat_vars.append(column)
        
    print("{} has {} unique values of type {}".format(column, len(df[column].unique()), df[column].dtype))

cat_vars.remove('total_points')
# Out:
# name has 982 unique values of type object
# season_x has 6 unique values of type object
# GW has 47 unique values of type float64
# position has 4 unique values of type object
# assists has 9 unique values of type float64
# bonus has 12 unique values of type float64
# bps has 215 unique values of type float64
# clean_sheets has 5 unique values of type float64
# creativity has 8258 unique values of type float64
# element has 1776 unique values of type float64
# goals_conceded has 20 unique values of type float64
# goals_scored has 11 unique values of type float64
# ict_index has 3505 unique values of type float64
# influence has 5525 unique values of type float64
# minutes has 337 unique values of type float64
# opponent_team has 20 unique values of type float64
# opp_team_name has 31 unique values of type object
# own_goals has 5 unique values of type float64
# penalties_missed has 5 unique values of type float64
# penalties_saved has 3 unique values of type float64
# red_cards has 4 unique values of type float64
# round has 167 unique values of type float64
# saves has 31 unique values of type float64
# selected has 82417 unique values of type float64
# team_a_score has 21 unique values of type float64
# team_h_score has 25 unique values of type float64
# threat has 324 unique values of type float64
# transfers_balance has 44907 unique values of type float64
# transfers_in has 38114 unique values of type float64
# transfers_out has 41767 unique values of type float64
# value has 313 unique values of type float64
# was_home has 5 unique values of type float64
# yellow_cards has 5 unique values of type float64
# total_points has 31 unique values of type int64

# %% [markdown]
# Examining the distribution for numerical features, numerical features with a small number of categories, and categorical features  ...

# %%
# Examine the distribution for numerical features (floats with 10+ unique values)

hist = df.hist(column=num_vars, layout=(7, 3), figsize=(20, 30))
for ax, column_name in zip(hist.flatten(), sorted(num_vars)):
    ax.set_title("Distribution of {}".format(column_name))
    ax.set_xlabel(column_name)
    ax.set_ylabel('count')

# %%
# Examine the distribution for numerical categorical features (floats with <10 unique values)

hist = df.hist(column=num_cat_vars, layout=(3,3), figsize=(20,13))
for ax, column_name in zip(hist.flatten(), sorted(num_cat_vars)):
    ax.set_title("Distribution of {}".format(column_name))
    ax.set_xlabel(column_name)
    ax.set_ylabel('count')

# %%
cat_vars
# Out:
# ['name', 'season_x', 'position', 'opp_team_name']

# %%
# Drop these as they are not categorical features we want to consider (just got included beacuse they are not floats)
for feature in ['name', 'season_x']: 
    cat_vars.remove(feature)

# %%
# Examine the distribution for categorical features (non float datatypes that aren't any of the above)

fig, axes = plt.subplots(nrows=1,ncols=2, figsize=(20,5))
for index, feature in enumerate(sorted(cat_vars)): 
    df[feature].value_counts().plot(ax=axes[index], subplots=True, kind='bar')

# %%
# Examine the distribution of y-labels

df.hist(column='total_points')
plt.title('Distribution of total_points')
plt.xlabel('total_points')
plt.ylabel('count')
plt.show()

# %% [markdown]
# Let's look at the correlation between features and target ...

# %%
# Split into df_x and df_y

df_x = df.drop(columns=['total_points'])
df_y = df['total_points']

# %%
# Examine the correlation with the target for numerical features (floats with 10+ unique values)

fig, axes = plt.subplots(7, 3, figsize=(20,35))
plt.subplots_adjust(hspace=0.3)
for ax, feature in zip(axes.flatten(), sorted(num_vars)): 
    ax.scatter(df_x[feature], df_y)
    ax.set_xlabel(feature)
    ax.set_ylabel('total_points')
    ax.set_title(f'Relationship between {feature} and total_points')

# %%
# Examine the correlation with the target for numerical categorical features (floats with <10 unique values)

fig, axes = plt.subplots(3, 3, figsize=(20,20))
plt.subplots_adjust(hspace = 0.3)

for ax, feature in zip(axes.flatten(), sorted(num_cat_vars)):
    df.boxplot(column=['total_points'], by=[feature], ax=ax)
    ax.set_xlabel(feature)
    ax.set_ylabel('total_points')
    ax.set_title(f'Relationship of {feature} with target')
    
plt.suptitle('');
fig.delaxes(axes[2][2])

# %%
# Examine the correlation with the target for categorical features

fig, axes = plt.subplots(2, 2, figsize=(10,10))

for index, feature in enumerate(sorted(cat_vars)): 
    x_subplot = index//2
    y_subplot = index%2
    boxplt = df.boxplot(column=['total_points'], by=[feature], ax=axes[x_subplot, y_subplot])
    boxplt.set_xlabel(feature)
    boxplt.set_ylabel('total_points')
    boxplt.set_title('')

# %% [markdown]
# Let's look at highly correlated features

# %%
corr_matrix = df_x.corr()
corr_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b7fb0_row0_col0, #T_b7fb0_row1_col1, #T_b7fb0_row2_col2, #T_b7fb0_row3_col3, #T_b7fb0_row4_col4, #T_b7fb0_row5_col5, #T_b7fb0_row6_col6, #T_b7fb0_row7_col7, #T_b7fb0_row8_col8, #T_b7fb0_row9_col9, #T_b7fb0_row10_col10, #T_b7fb0_row11_col11, #T_b7fb0_row12_col12, #T_b7fb0_row13_col13, #T_b7fb0_row14_col14, #T_b7fb0_row15_col15, #T_b7fb0_row16_col16, #T_b7fb0_row17_col17, #T_b7fb0_row18_col18, #T_b7fb0_row19_col19, #T_b7fb0_row20_col20, #T_b7fb0_row21_col21, #T_b7fb0_row22_col22, #T_b7fb0_row23_col23, #T_b7fb0_row24_col24, #T_b7fb0_row25_col25, #T_b7fb0_row26_col26, #T_b7fb0_row27_col27 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col1, #T_b7fb0_row0_col8, #T_b7fb0_row1_col17, #T_b7fb0_row4_col14, #T_b7fb0_row4_col26, #T_b7fb0_row5_col6, #T_b7fb0_row7_col6, #T_b7fb0_row8_col17, #T_b7fb0_row9_col12, #T_b7fb0_row9_col14, #T_b7fb0_row10_col16, #T_b7fb0_row16_col1, #T_b7fb0_row18_col6, #T_b7fb0_row20_col26, #T_b7fb0_row21_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col2, #T_b7fb0_row1_col13, #T_b7fb0_row14_col27, #T_b7fb0_row21_col6, #T_b7fb0_row21_col16 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col3, #T_b7fb0_row14_col20, #T_b7fb0_row15_col21 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col4, #T_b7fb0_row9_col13, #T_b7fb0_row14_col19, #T_b7fb0_row17_col6, #T_b7fb0_row19_col1, #T_b7fb0_row19_col8, #T_b7fb0_row23_col17, #T_b7fb0_row23_col20, #T_b7fb0_row25_col27 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col5, #T_b7fb0_row10_col13, #T_b7fb0_row16_col5, #T_b7fb0_row18_col16, #T_b7fb0_row22_col0, #T_b7fb0_row27_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col6, #T_b7fb0_row13_col9, #T_b7fb0_row13_col25, #T_b7fb0_row16_col6, #T_b7fb0_row24_col7 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b7fb0_row0_col7, #T_b7fb0_row4_col0, #T_b7fb0_row12_col0, #T_b7fb0_row12_col1, #T_b7fb0_row13_col0, #T_b7fb0_row15_col1, #T_b7fb0_row16_col2, #T_b7fb0_row20_col27, #T_b7fb0_row26_col0, #T_b7fb0_row26_col27 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col9, #T_b7fb0_row0_col10, #T_b7fb0_row0_col25, #T_b7fb0_row15_col20, #T_b7fb0_row17_col20, #T_b7fb0_row17_col25, #T_b7fb0_row22_col16, #T_b7fb0_row23_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col11, #T_b7fb0_row11_col20, #T_b7fb0_row12_col17, #T_b7fb0_row12_col21, #T_b7fb0_row13_col2, #T_b7fb0_row16_col11, #T_b7fb0_row25_col13, #T_b7fb0_row26_col18 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col12, #T_b7fb0_row16_col12, #T_b7fb0_row21_col17 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col13, #T_b7fb0_row1_col12, #T_b7fb0_row1_col14, #T_b7fb0_row3_col6, #T_b7fb0_row3_col15, #T_b7fb0_row6_col15, #T_b7fb0_row7_col0, #T_b7fb0_row8_col14, #T_b7fb0_row16_col15, #T_b7fb0_row16_col23, #T_b7fb0_row19_col26, #T_b7fb0_row22_col12, #T_b7fb0_row26_col12, #T_b7fb0_row27_col26 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col14, #T_b7fb0_row0_col23, #T_b7fb0_row2_col15, #T_b7fb0_row6_col4, #T_b7fb0_row11_col0, #T_b7fb0_row11_col26, #T_b7fb0_row12_col14, #T_b7fb0_row13_col14, #T_b7fb0_row13_col15, #T_b7fb0_row14_col15, #T_b7fb0_row19_col13, #T_b7fb0_row19_col14, #T_b7fb0_row20_col13, #T_b7fb0_row26_col14 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col15, #T_b7fb0_row0_col26, #T_b7fb0_row4_col20, #T_b7fb0_row5_col12, #T_b7fb0_row6_col26, #T_b7fb0_row10_col6, #T_b7fb0_row12_col13, #T_b7fb0_row14_col13, #T_b7fb0_row14_col26, #T_b7fb0_row15_col12, #T_b7fb0_row15_col13, #T_b7fb0_row16_col13, #T_b7fb0_row16_col26, #T_b7fb0_row17_col15, #T_b7fb0_row17_col26, #T_b7fb0_row24_col26, #T_b7fb0_row27_col14 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col16, #T_b7fb0_row16_col0 {
#   background-color: #ca3b37;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col17, #T_b7fb0_row0_col20, #T_b7fb0_row2_col6, #T_b7fb0_row11_col12, #T_b7fb0_row13_col17, #T_b7fb0_row13_col27, #T_b7fb0_row15_col17, #T_b7fb0_row16_col17, #T_b7fb0_row16_col19, #T_b7fb0_row19_col17, #T_b7fb0_row20_col23, #T_b7fb0_row24_col15 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col18, #T_b7fb0_row11_col19, #T_b7fb0_row12_col18, #T_b7fb0_row16_col18, #T_b7fb0_row17_col19, #T_b7fb0_row19_col5, #T_b7fb0_row19_col21, #T_b7fb0_row24_col20, #T_b7fb0_row24_col27, #T_b7fb0_row26_col19, #T_b7fb0_row26_col20 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col19, #T_b7fb0_row2_col16, #T_b7fb0_row12_col8, #T_b7fb0_row14_col23, #T_b7fb0_row15_col2, #T_b7fb0_row15_col27, #T_b7fb0_row17_col16, #T_b7fb0_row19_col2, #T_b7fb0_row19_col27, #T_b7fb0_row20_col16, #T_b7fb0_row26_col1, #T_b7fb0_row26_col23 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col21, #T_b7fb0_row4_col16, #T_b7fb0_row7_col14, #T_b7fb0_row14_col21, #T_b7fb0_row15_col23, #T_b7fb0_row16_col21, #T_b7fb0_row26_col16 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col22, #T_b7fb0_row16_col22, #T_b7fb0_row17_col7, #T_b7fb0_row17_col22, #T_b7fb0_row20_col24 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b7fb0_row0_col24, #T_b7fb0_row7_col1, #T_b7fb0_row17_col4, #T_b7fb0_row17_col18, #T_b7fb0_row25_col7 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b7fb0_row0_col27, #T_b7fb0_row5_col0, #T_b7fb0_row5_col26, #T_b7fb0_row9_col26, #T_b7fb0_row11_col16, #T_b7fb0_row16_col27, #T_b7fb0_row17_col27, #T_b7fb0_row21_col26, #T_b7fb0_row25_col15, #T_b7fb0_row27_col0, #T_b7fb0_row27_col12 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_b7fb0_row1_col0, #T_b7fb0_row3_col16, #T_b7fb0_row4_col6, #T_b7fb0_row8_col0, #T_b7fb0_row11_col15, #T_b7fb0_row18_col14, #T_b7fb0_row20_col0, #T_b7fb0_row27_col16 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b7fb0_row1_col2, #T_b7fb0_row3_col23, #T_b7fb0_row4_col21, #T_b7fb0_row21_col1, #T_b7fb0_row23_col5, #T_b7fb0_row25_col23 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_b7fb0_row1_col3, #T_b7fb0_row9_col18, #T_b7fb0_row21_col2 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_b7fb0_row1_col4, #T_b7fb0_row1_col18, #T_b7fb0_row7_col22, #T_b7fb0_row8_col4, #T_b7fb0_row15_col24, #T_b7fb0_row24_col11, #T_b7fb0_row27_col24 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_b7fb0_row1_col5, #T_b7fb0_row4_col9 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b7fb0_row1_col6, #T_b7fb0_row5_col13, #T_b7fb0_row6_col20, #T_b7fb0_row8_col6, #T_b7fb0_row12_col27, #T_b7fb0_row13_col1, #T_b7fb0_row27_col20 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_b7fb0_row1_col7, #T_b7fb0_row4_col1, #T_b7fb0_row4_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b7fb0_row1_col8, #T_b7fb0_row2_col7, #T_b7fb0_row5_col27, #T_b7fb0_row8_col1 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_b7fb0_row1_col9, #T_b7fb0_row21_col11, #T_b7fb0_row23_col24 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_b7fb0_row1_col10, #T_b7fb0_row2_col11 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b7fb0_row1_col11, #T_b7fb0_row2_col23, #T_b7fb0_row3_col25, #T_b7fb0_row25_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b7fb0_row1_col15, #T_b7fb0_row1_col26, #T_b7fb0_row2_col26, #T_b7fb0_row4_col15, #T_b7fb0_row10_col0, #T_b7fb0_row10_col26, #T_b7fb0_row16_col14, #T_b7fb0_row20_col12, #T_b7fb0_row20_col15, #T_b7fb0_row21_col12, #T_b7fb0_row22_col13, #T_b7fb0_row24_col14, #T_b7fb0_row26_col15, #T_b7fb0_row27_col15 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b7fb0_row1_col16, #T_b7fb0_row2_col13, #T_b7fb0_row6_col17, #T_b7fb0_row8_col16, #T_b7fb0_row10_col12, #T_b7fb0_row12_col23, #T_b7fb0_row14_col0, #T_b7fb0_row15_col8, #T_b7fb0_row15_col16, #T_b7fb0_row16_col7, #T_b7fb0_row27_col17 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b7fb0_row1_col19, #T_b7fb0_row4_col17, #T_b7fb0_row7_col4, #T_b7fb0_row12_col7, #T_b7fb0_row20_col10, #T_b7fb0_row24_col1, #T_b7fb0_row27_col25 {
#   background-color: #7b9ff

# %%
# Take a loot at the most highly correlated features

df_x.corr().abs().unstack().sort_values(kind='quicksort')[-41:-31]
# Out:
# ict_index  creativity    0.817518
# influence  minutes       0.817655
# minutes    influence     0.817655
# influence  ict_index     0.850082
# ict_index  influence     0.850082
# bps        minutes       0.856918
# minutes    bps           0.856918
# threat     ict_index     0.864673
# ict_index  threat        0.864673
# bps        influence     0.934918
# dtype: float64

# %% [markdown]
# # Let's try to apply some models on the raw data (purely on individual player data)

# %% [markdown]
# We'll start with decision trees becuase these handle categorical features on the fly

# %%
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
# Get rid of any non-individual statistics or statistics that don't capture player performance
non_individual_stats = ['name', 'season_x', 'kickoff_time', 'opponent_team', 'opp_team_name', 'team_a_score', 'team_h_score', 'GW']
df_x = df_x.drop(columns=non_individual_stats, errors='ignore')

# Split the dataset into train and test using STRUCTURED SPLITTING
x_dev, x_test, y_dev, y_test = train_test_split(df_x, df_y, test_size = 0.2, shuffle=False)

# Fit the random forest classifier
preprocess = make_column_transformer((OneHotEncoder(handle_unknown="ignore"), ['position']), remainder="passthrough")
pipe = make_pipeline(preprocess, RandomForestClassifier())
pipe.fit(x_dev, y_dev)

# Test accuracies on the most recent 20% of data
y_pred = pipe.predict(x_test)

print("Mean Absolute Error: " + str(mean_absolute_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 1.2218344197505517

# %%
# Build the list of feature names
ohe_feature_names = preprocess.named_transformers_["onehotencoder"].get_feature_names().tolist()
ohe_feature_names = [x[3:] for x in ohe_feature_names]
feature_names = ohe_feature_names + list(df_x.drop(columns=['position']).columns)

# Get the importance of features
feat_imps = zip(feature_names, pipe[1].feature_importances_)
feats, imps = zip(*(sorted(list(filter(lambda x: x[1] != 0, feat_imps)), key=lambda x: x[1], reverse=True)))

# Plot the results
ax = sns.barplot(list(feats), list(imps))
ax.tick_params(axis='x', rotation=90)
ax.set_title('Feature Importances for Random Forest Pipe')
ax.set_ylabel('Feature Importance')
plt.show()
